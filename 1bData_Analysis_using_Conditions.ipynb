# %% [markdown]
# <a href="https://colab.research.google.com/github/swarubm/data-analysis-projects-/blob/main/1bData_Analysis_using_Conditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('googleplaystore.csv')

impute = SimpleImputer(missing_values = np.nan , strategy = 'mean')
impute.fit(df.iloc[ : , 2:3 ].values)
df.iloc[ : , 2:3 ] = impute.transform(df.iloc[ : , 2:3 ].values)

df = df.dropna()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %% [markdown]
# # what row is having category = productivity will be appeared

# %%
df_s= df[df['Category'] == 'PRODUCTIVITY']
df_s
# Out:
#                                                      App      Category  \
# 3450                                      Microsoft Word  PRODUCTIVITY
# 3451   All-In-One Toolbox: Cleaner, Booster, App Manager  PRODUCTIVITY
# 3452                                Adobe Acrobat Reader  PRODUCTIVITY
# 3453       AVG Cleaner – Speed, Battery & Memory Booster  PRODUCTIVITY
# 3454                                        Google Drive  PRODUCTIVITY
# ...                                                  ...           ...
# 10606                                      Fort Myers FL  PRODUCTIVITY
# 10622                                     MY GULFPORT FL  PRODUCTIVITY
# 10681                                       Future Cloud  PRODUCTIVITY
# 10771                                           FQ METER  PRODUCTIVITY
# 10822                                          PLMGSS FR  PRODUCTIVITY
#
#          Rating  Reviews                Size        Installs  Type Price  \
# 3450   4.500000  2084126  Varies with device    500,000,000+  Free     0
# 3451   4.700000   536926  Varies with device     10,000,000+  Free     0
# 3452   4.300000  3016297  Varies with device    100,000,000+  Free     0
# 3453   4.400000  1188154                 24M     10,000,000+  Free     0
# 3454   4.400000  2731171  Varies with device  1,000,000,000+  Free     0
# ...         ...      ...                 ...             ...   ...   ...
# 10606  4.193338        0                 22M            100+  Free     0
# 10622  4.193338        0                 49M             50+  Free     0
# 10681  4.600000     1075  Varies with device        100,000+  Free     0
# 10771  3.900000       17                2.4M          1,000+  Free     0
# 10822  4.193338        0                3.1M             10+  Free     0
#
#       Content Rating        Genres        Last Updated         Current Ver  \
# 3450        Everyone  Productivity       July 11, 2018    16.0.10325.20043
# 3451        Everyone  Productivity      August 5, 2018  Varies with device
# 3452        Everyone  Productivity      April 17, 2018  Varies with device
# 3453        Everyone  Productivity       June 14, 2018               4.6.4
# 3454        Everyone  Productivity      August 6, 2018  Varies with device
# ...              ...           ...                 ...                 ...
# 10606       Everyone  Productivity  September 17, 2015               2.4.0
# 10622       Everyone  Productivity        May 18, 2018                17.4
# 10681       Everyone  Productivity    January 22, 2018  Varies with device
# 10771       Everyone  Productivity      April 23, 2017                 1.1
# 10822       Everyone  Productivity    December 1, 2017                   1
#
#               Android Ver
# 3450           4.4 and up
# 3451   Varies with device
# 3452   Varies with device
# 3453           4.1 and up
# 3454   Varies with device
# ...                   ...
# 10606          4.1 and up
# 10622          4.1 and up
# 10681          4.4 and up
# 10771          4.0 and up
# 10822          4.4 and up
#
# [424 rows x 13 columns]

# %%
df[df['Category'] == 'PRODUCTIVITY']
# Out:
#                                                      App      Category  \
# 3450                                      Microsoft Word  PRODUCTIVITY
# 3451   All-In-One Toolbox: Cleaner, Booster, App Manager  PRODUCTIVITY
# 3452                                Adobe Acrobat Reader  PRODUCTIVITY
# 3453       AVG Cleaner – Speed, Battery & Memory Booster  PRODUCTIVITY
# 3454                                        Google Drive  PRODUCTIVITY
# ...                                                  ...           ...
# 10606                                      Fort Myers FL  PRODUCTIVITY
# 10622                                     MY GULFPORT FL  PRODUCTIVITY
# 10681                                       Future Cloud  PRODUCTIVITY
# 10771                                           FQ METER  PRODUCTIVITY
# 10822                                          PLMGSS FR  PRODUCTIVITY
#
#          Rating  Reviews                Size        Installs  Type Price  \
# 3450   4.500000  2084126  Varies with device    500,000,000+  Free     0
# 3451   4.700000   536926  Varies with device     10,000,000+  Free     0
# 3452   4.300000  3016297  Varies with device    100,000,000+  Free     0
# 3453   4.400000  1188154                 24M     10,000,000+  Free     0
# 3454   4.400000  2731171  Varies with device  1,000,000,000+  Free     0
# ...         ...      ...                 ...             ...   ...   ...
# 10606  4.193338        0                 22M            100+  Free     0
# 10622  4.193338        0                 49M             50+  Free     0
# 10681  4.600000     1075  Varies with device        100,000+  Free     0
# 10771  3.900000       17                2.4M          1,000+  Free     0
# 10822  4.193338        0                3.1M             10+  Free     0
#
#       Content Rating        Genres        Last Updated         Current Ver  \
# 3450        Everyone  Productivity       July 11, 2018    16.0.10325.20043
# 3451        Everyone  Productivity      August 5, 2018  Varies with device
# 3452        Everyone  Productivity      April 17, 2018  Varies with device
# 3453        Everyone  Productivity       June 14, 2018               4.6.4
# 3454        Everyone  Productivity      August 6, 2018  Varies with device
# ...              ...           ...                 ...                 ...
# 10606       Everyone  Productivity  September 17, 2015               2.4.0
# 10622       Everyone  Productivity        May 18, 2018                17.4
# 10681       Everyone  Productivity    January 22, 2018  Varies with device
# 10771       Everyone  Productivity      April 23, 2017                 1.1
# 10822       Everyone  Productivity    December 1, 2017                   1
#
#               Android Ver
# 3450           4.4 and up
# 3451   Varies with device
# 3452   Varies with device
# 3453           4.1 and up
# 3454   Varies with device
# ...                   ...
# 10606          4.1 and up
# 10622          4.1 and up
# 10681          4.4 and up
# 10771          4.0 and up
# 10822          4.4 and up
#
# [424 rows x 13 columns]

# %% [markdown]
# # Q1. How many free apps are there in ART_AND_DESIGN?

# %%
df_pr = df[df['Category'] == 'ART_AND_DESIGN']
print(len(df_pr[df_pr['Type'] == 'Free']))
# Out:
# 61

# %% [markdown]
# # Q2. How many apps are there in ART_AND_DESIGN with rating more then 4.5?

# %%
df_pr = df[df['Category'] == 'ART_AND_DESIGN']
print(len(df_pr[df_pr['Rating'] > 4.5]))
# Out:
# 22

# %% [markdown]
# # Q3. How many apps are there in FAMILY with rating more then 4.5 and Free?

# %%
df_pr = df[df['Category'] == 'FAMILY']
df_pr = df_pr[df_pr['Rating'] > 4.5]

len(df_pr[df_pr['Type'] == 'Free'])
# Out:
# 314

# %% [markdown]
# # Q4. List all the free apps with rating more then 4.5 and category is FAMILY?

# %%
df_pr = df[df['Category'] == 'FAMILY']
df_pr = df_pr[df_pr['Rating'] > 4.5]

df_pr[df_pr['Type'] == 'Free']
# Out:
#                                                      App Category  Rating  \
# 2020   Super ABC! Learning games for kids! Preschool ...   FAMILY     4.6
# 2023                                     Candy Pop Story   FAMILY     4.7
# 2029                         Dog Run - Pet Dog Simulator   FAMILY     4.7
# 2032     Puzzle Kids - Animals Shapes and Jigsaw Puzzles   FAMILY     4.6
# 2040        No. Color - Color by Number, Number Coloring   FAMILY     4.8
# ...                                                  ...      ...     ...
# 10691                                             Pin-fo   FAMILY     4.6
# 10801                                Fr Ignacio Outreach   FAMILY     4.9
# 10809              Castle Clash: RPG War and Strategy FR   FAMILY     4.7
# 10820                                    Fr. Daoud Lamei   FAMILY     5.0
# 10837                   Fr. Mike Schmitz Audio Teachings   FAMILY     5.0
#
#       Reviews  Size     Installs  Type Price Content Rating  \
# 2020    20267   46M   1,000,000+  Free     0       Everyone
# 2023    12948   23M   1,000,000+  Free     0       Everyone
# 2029    48615   24M  10,000,000+  Free     0       Everyone
# 2032     1109   52M   1,000,000+  Free     0       Everyone
# 2040   269194  6.9M  10,000,000+  Free     0       Everyone
# ...       ...   ...          ...   ...   ...            ...
# 10691      19  1.6M         500+  Free     0       Everyone
# 10801      52   19M       1,000+  Free     0       Everyone
# 10809  376223   24M   1,000,000+  Free     0       Everyone
# 10820      22  8.6M       1,000+  Free     0           Teen
# 10837       4  3.6M         100+  Free     0       Everyone
#
#                               Genres      Last Updated           Current Ver  \
# 2020           Educational;Education     July 16, 2018               1.1.6.7
# 2023              Casual;Brain Games      May 24, 2018              2.0.3165
# 2029   Simulation;Action & Adventure      May 22, 2018                1.4.12
# 2032         Educational;Brain Games     July 18, 2018                 1.0.6
# 2040       Entertainment;Brain Games    August 3, 2018    Varies with device
# ...                              ...               ...                   ...
# 10691                  Entertainment   August 15, 2016  3rd Release Aug 2016
# 10801                      Education  January 19, 2018                   1.0
# 10809                       Strategy     July 18, 2018                 1.4.2
# 10820                      Education     June 27, 2018                 3.8.0
# 10837                      Education      July 6, 2018                   1.0
#
#               Android Ver
# 2020           4.1 and up
# 2023           2.3 and up
# 2029           4.1 and up
# 2032           4.1 and up
# 2040   Varies with device
# ...                   ...
# 10691          2.2 and up
# 10801          4.4 and up
# 10809          4.1 and up
# 10820          4.1 and up
# 10837          4.1 and up
#
# [314 rows x 13 columns]
